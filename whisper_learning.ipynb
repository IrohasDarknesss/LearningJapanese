# %% [markdown]
# <a href="https://colab.research.google.com/github/IrohasDarknesss/LearningJapanese/blob/main/whisper_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 利用ライブラリのインストール
! pip install git+https://github.com/openai/whisper.git
! pip install git+https://github.com/dai-pop/videogrep.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-ju1oi8t4
#   Running command git clone -q https://github.com/openai/whisper.git /tmp/pip-req-build-ju1oi8t4
# ...
#      |████████████████████████████████| 4.9 MB 35.4 MB/s
# ...
#      |████████████████████████████████| 163 kB 59.4 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 63.2 MB/s
# ...
#   Created wheel for whisper: filename=whisper-1.0-py3-none-any.whl size=1175010 sha256=ee6aaeed4681657385862801392d62c77865bebc7115e7e662187c8a9ce278c6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ikirhxmb/wheels/16/15/89/1c7bb31bd0006793a95549d04785121a8a36daad9158e1e43a
# Successfully built whisper
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/dai-pop/videogrep.git to /tmp/pip-req-build-v1v12swr
# ...

# %%
# google driveをマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 動画ファイルのディレクトリに移動
# %cd "/content/drive/MyDrive/movie"
# Out:
# /content/drive/MyDrive/movie

# %%
# 音声ファイル作成
import glob
from pathlib import Path

for mp4file in glob.glob("*.mp4"):
  wavfile = Path(mp4file).stem + ".wav"
  ! ffmpeg -i $mp4file $wavfile
# Out:
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# 音声認識
for wavfile in glob.glob("*.wav"):
  ! whisper --model base --language Japanese $wavfile
# Out:
# [00:00.000 --> 00:02.000] ラプラスドアイクですだ!
# [00:03.280 --> 00:04.960] ピッククソ関係ないけどラップ様に
# [00:04.960 --> 00:06.440] 恋愛相談してみてもしい
# [00:06.440 --> 00:08.360] スーパンチャートで連愛相談してください
# [00:08.360 --> 00:09.720] ただでじゃ乗りませんから
# [00:09.720 --> 00:11.080] ではちょっと広い気みたいにありたい
# [00:11.080 --> 00:12.120] 広い気みたいに
# [00:12.120 --> 00:13.760] 好きな操水がいるのですが
# [00:13.760 --> 00:14.460] 乳してるやん
# [00:14.460 --> 00:15.560] 本人に言うな
# [00:15.560 --> 00:17.000] この好きな人がずっと頭に
# [00:17.000 --> 00:18.040] つのつけてるんですけど
# [00:18.040 --> 00:18.920] 正直邪魔です
# [00:18.920 --> 00:20.160] 妖精は伝えられます
# [00:20.160 --> 00:20.960] ほんや
# [00:20.960 --> 00:22.560] 今日の番ごはんはカレーライス
# [00:22.560 --> 00:24.160] 決まってんだら言ってくんだよ
# [00:24.160 --> 00:25.480] 二戦者に乗れないうちに
# [00:25.480 --> 00:26.640] チェーンがさびてしまったら
# [00:26.640 --> 00:27.840] どうせる場合ですか
# [00:27.840 --> 00:30.160] 自転車屋さん行けよー
# [00:30.160 --> 00:31.360] ガナナのミソニーコミ
# [00:31.360 --> 00:32.360] 全然欲しくなさそう
# [00:32.360 --> 00:33.760] のは乗る乗るしていますか
# [00:33.760 --> 00:34.840] それ疑問じゃん
# ...

# %%
# vttファイルをリネーム
import glob
import shutil
for vttfile in glob.glob("*.wav.vtt"):
  shutil.move(vttfile, vttfile.replace(".wav.vtt",".vtt"))

# %%
# 動画作成
# !videogrep --input *.mp4 --search 悪魔的 --output output.mp4
# Out:
# No subtitle file found for  output.mp4
# [+] Creating clips.
# [+] Concatenating clips.
# [+] Writing ouput file.
# Moviepy - Building video output.mp4.
# MoviePy - Writing audio in temp-audio1665044603.0915244.m4a
# MoviePy - Done.
# Moviepy - Writing video output.mp4
#
# Moviepy - Done !
# Moviepy - video ready output.mp4
